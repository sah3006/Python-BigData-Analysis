# %% [markdown]
# ## IMDB_BORN_Today_sentimental_analysis

# %% [markdown]
# http://m.imdb.com/feature/bornondate
#
# My goal for this part is get the list of these celebrities from this webpage using web scraping top and 10 celebrities and extract the below information:
# 1.	Name of the celebrity:
# 2.	Celebrity Image:
# 3.	Profession:
# 4.	Best Work:
# 5.  Then search their public twitters account to get the overall Sentiment based the birthday wishes as Positive, Negative or Neutral.

# %%
# Md Afzal Hossain


# Below are the step which were followed To scrape data from IMDB website :http://m.imdb.com/feature/bornondate
# Installed selenium driver using PIP (pip install selenium)
# After installing selenium driver installed chrome web driver(latest version in downloads directory)
# The set up file of chrome web driver was saved in Anaconda directory
# Then installed BeautifulSoup(bs4) package via pip installation
# Installed textblob package for sentiment analysis:
# TextBlob is a Python  3 library for processing textual data.
# It provides a consistent API for diving into common natural language processing (NLP)
# tweepy installed



# Need To import webdriver from selenium package

from selenium import webdriver
from bs4 import BeautifulSoup as bs

driver = webdriver.Chrome("/Users/afzal/Documents/chromedriver")

driver.get("http://m.imdb.com/feature/bornondate")

html = driver.page_source
driver.close()

soup = bs(html, 'lxml')
# print soup.prettify()
##for tags in soup.currentTag():
## print tags

##celeb_records = soup.find_all('a')
##for info in celeb_records:
## print info

## step 1 : Iterating through names of celebrities

celeb_name = []
name = soup.find_all('span', class_='title')

for info in name:
    # print info.text
    celeb_name.append(info.text)

## step 2 : Iterating through details of celebrities
# below are the list of celebrities detail

celeb_detail = []
detail = soup.find_all('div', class_="detail")
for details in detail:
    # print details.text
    celeb_detail.append(details.text)

celeb_images = []
images = soup.find_all('a', class_='poster')
for image in images:
    # print image.img["src"]
    celeb_images.append(image.img["src"])



print("Sentiment Analysis for Birthday Celebrities:")
print('--------------------------------------------------------------------------------------------')
#print("Name of Celebrity , celebrity image , Profession and Best Work : ")




def celebrities():
    print(' Celebrities Name:  ' + (celeb_name[0]), '\n', ' Profession : ' + (
    celeb_detail[0].split(',')[0]), '\n', ' Best Work : ' + (
    celeb_detail[0].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[0]), '\n')
    print(' Celebrities Name:  ' + (celeb_name[1]), '\n', ' Profession : ' + (
    celeb_detail[1].split(',')[0]), '\n', ' Best Work : ' + (
    celeb_detail[1].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[1]), '\n')
    print(' Celebrities Name:  ' + (celeb_name[2]), '\n', ' Profession : ' + (
    celeb_detail[2].split(',')[0]), '\n', ' Best Work : ' + (
    celeb_detail[2].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[2]), '\n')
    print(' Celebrities Name:  ' + (celeb_name[3]), '\n', ' Profession : ' + (
    celeb_detail[3].split(',')[0]), '\n', ' Best Work : ' + (
    celeb_detail[3].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[3]), '\n')
    print(' Celebrities Name:  ' + (celeb_name[4]), '\n', ' Profession : ' + (
    celeb_detail[4].split(',')[0]), '\n', ' Best Work : ' + (
    celeb_detail[4].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[4]), '\n')
    print(' Celebrities Name:  ' + (celeb_name[5]), '\n', ' Profession : ' + (
    celeb_detail[5].split(',')[0]), '\n', ' Best Work : ' + (
    celeb_detail[5].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[5]), '\n')
    print(' Celebrities Name:  ' + (celeb_name[6]), '\n', ' Profession : ' + (
    celeb_detail[6].split(',')[0]), '\n', ' Best Work : ' + (
    celeb_detail[6].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[6]), '\n')
    print(' Celebrities Name:  ' + (celeb_name[7]), '\n', ' Profession : ' + (
    celeb_detail[7].split(',')[0]), '\n', ' Best Work : ' + (
    celeb_detail[7].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[7]), '\n')
    print(' Celebrities Name:  ' + (celeb_name[8]), '\n', ' Profession : ' + (
    celeb_detail[8].split(',')[0]), '\n', ' Best Work : ' + (
    celeb_detail[8].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[8]), '\n')
    print(' Celebrities Name:  ' + (celeb_name[9]), '\n', ' Profession : ' + (
    celeb_detail[9].split(',')[0]), '\n', ' Best Work : ' + (
    celeb_detail[9].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[9]), '\n')
    # data = zip(celeb_detail, celeb_name)
    # print "Below are the list of celebrity names ,their profession  and Best Work:"
    # for sample in enumerate(data, +1):
    #     print list(sample)


def Final_Output():
    from textblob import TextBlob
    import tweepy
    from tweepy.auth import OAuthHandler


    ckey = '9XKyjq769fZ883HfB8KbWT7AN'
    csecret = 'sLXPcbkMEE90EfeaQMw7w89mg8O0yap5QXqryueQ7xw5pUG0St'

    atoken = '393538660-CpHqO86niQJVBCdPgDYd7uKtF1ubDogIlSZ3DtQo'
    asecret = '3VfgebGM7IAdLqsz5Hm1hKD5pCN5KrJlocSco8lmBx0DP'

    auth = OAuthHandler(ckey, csecret)
    auth.set_access_token(atoken, asecret)
    api = tweepy.API(auth)
    public_tweets = api.search(celeb_name[0])
    public_tweets1 = api.search(celeb_name[1])
    public_tweets2 = api.search(celeb_name[2])
    public_tweets3 = api.search(celeb_name[3])
    public_tweets4 = api.search(celeb_name[4])
    public_tweets5 = api.search(celeb_name[5])
    public_tweets6 = api.search(celeb_name[6])
    public_tweets7 = api.search(celeb_name[7])
    public_tweets8 = api.search(celeb_name[8])
    public_tweets9 = api.search(celeb_name[9])

    ####################################################################################
    # print "\n\n\n"

    print("List of tweets for celebrity %s -> " % (celeb_name[0]))
    for tweets in public_tweets:
        # print "***************************************"
        print(tweets.text)
        analysis = TextBlob(tweets.text)
        print("Tweet sentiment.polarity :", analysis.sentiment.polarity)
        print("Tweet sentiment.subjectivity :", analysis.sentiment.subjectivity)

        print('\n\n\n')

        #print ("The sentiment analysis of this tweet for %s is:" % (celeb_name[0]))
        #
        # if analysis.sentiment.polarity > 0:
        #     print  ['positive']
        # if analysis.sentiment.polarity == 0:
        #     print ['neutral']
        # if analysis.sentiment.polarity < 0:
        #     print ['negative']

    def Overall_sentiment():
        positive = analysis.sentiment.polarity > 0
        neutral = analysis.sentiment.polarity == 0
        negative = analysis.sentiment.polarity < 0

        if positive > negative:
            return "POSITIVE"

        elif positive < negative:
            return "NEGATIVE"
        else:
            return "NEUTRAL"

    # print ('\n\n\n')

    tweet_zero = "The Overall sentiment for %s is :" % celeb_name[0], Overall_sentiment()


    # print ("\n\n\n\n")

    #######################################################################################
    print ("List of tweets for celebrity %s -> " % (celeb_name[1]))

    for tweets in public_tweets1:
        # print ("***********************************")
        print (tweets.text)
        analysis = TextBlob(tweets.text)
        # print ("Tweet sentiment.polarity :", analysis.sentiment.polarity)
        # print ("Tweet sentiment.subjectivity :", analysis.sentiment.subjectivity)

        # print ('\n\n\n')

        # print ("The sentiment analysis of this tweet for  %s is:" % (celeb_name[1]))

        # if analysis.sentiment.polarity > 0:
        #     print 'positive'
        # if analysis.sentiment.polarity == 0:
        #     print 'neutral'
        # if analysis.sentiment.polarity < 0:
        #     print 'negative'

    def Overall_sentiment1():
        positive = analysis.sentiment.polarity > 0
        neutral = analysis.sentiment.polarity == 0
        negative = analysis.sentiment.polarity < 0

        if positive > negative:
            return "POSITIVE"

        elif positive < negative:
            return "NEGATIVE"
        else:
            return "NEUTRAL"

    # print ('\n\n\n')

    tweet_first = "The Overall sentiment for %s is :" % celeb_name[1], Overall_sentiment1()


    # print ("\n\n\n\n")

    #######################################################################################
    # print ("List of tweets for celebrity %s -> " % (celeb_name[2]))

    for tweets in public_tweets2:
        # print ("***********************************")
        # print (tweets.text)
        analysis = TextBlob(tweets.text)
        # print ("Tweet sentiment.polarity :", analysis.sentiment.polarity)
        # print ("Tweet sentiment.subjectivity :", analysis.sentiment.subjectivity)

        # print ('\n\n\n')

        # print ("The sentiment analysis of this tweet for  %s is:" % (celeb_name[2]))

        # if analysis.sentiment.polarity > 0:
        #     print 'positive'
        # if analysis.sentiment.polarity == 0:
        #     print 'neutral'
        # if analysis.sentiment.polarity < 0:
        #     print 'negative'

    def Overall_sentiment2():
        positive = analysis.sentiment.polarity > 0
        neutral = analysis.sentiment.polarity == 0
        negative = analysis.sentiment.polarity < 0

        if positive > negative:
            return "POSITIVE"

        elif positive < negative:
            return "NEGATIVE"
        else:
            return "NEUTRAL"

    # print ('\n\n\n')

    tweet_second = "The Overall sentiment for %s is :" % celeb_name[2], Overall_sentiment2()


    # print ("\n\n\n\n")

    #######################################################################################


    # print ("List of tweets for celebrity %s -> " % (celeb_name[3]))

    for tweets in public_tweets3:
        # print "***********************************"
        # print tweets.text
        analysis = TextBlob(tweets.text)
        # print ("Tweet sentiment.polarity :", analysis.sentiment.polarity)
        # print ("Tweet sentiment.subjectivity :", analysis.sentiment.subjectivity)

        # print ('\n\n\n')

        #print("The sentiment analysis of this tweet for  %s is:" % (celeb_name[3]))

        # if analysis.sentiment.polarity > 0:
        #     print 'positive'
        # if analysis.sentiment.polarity == 0:
        #     print 'neutral'
        # if analysis.sentiment.polarity < 0:
        #     print 'negative'

    def Overall_sentiment3():
        positive = analysis.sentiment.polarity > 0
        neutral = analysis.sentiment.polarity == 0
        negative = analysis.sentiment.polarity < 0

        if positive > negative:
            return "POSITIVE"

        elif positive < negative:
            return "NEGATIVE"
        else:
            return "NEUTRAL"

    # print ('\n\n\n')

    tweet_third = "The Overall sentiment for %s is :" % celeb_name[3], Overall_sentiment3()


    # print ("\n\n\n\n")

    #######################################################################################


    # print ("List of tweets for celebrity %s -> " % (celeb_name[4]))

    for tweets in public_tweets4:
        # print ("***********************************")
        # print (tweets.text)
        analysis = TextBlob(tweets.text)
        # print ("Tweet sentiment.polarity :", analysis.sentiment.polarity)
        # print ("Tweet sentiment.subjectivity :", analysis.sentiment.subjectivity)

        # print ('\n\n\n')

        # print ("The sentiment analysis of this tweet for  %s is:" % (celeb_name[4]))

        # if analysis.sentiment.polarity > 0:
        #     print 'positive'
        # if analysis.sentiment.polarity == 0:
        #     print 'neutral'
        # if analysis.sentiment.polarity < 0:
        #     print 'negative'

    def Overall_sentiment4():
        positive = analysis.sentiment.polarity > 0
        neutral = analysis.sentiment.polarity == 0
        negative = analysis.sentiment.polarity < 0

        if positive > negative:
            return "POSITIVE"

        elif positive < negative:
            return "NEGATIVE"
        else:
            return "NEUTRAL"

    # print ('\n\n\n')

    tweet_fourth = "The Overall sentiment for %s is :" % celeb_name[4], Overall_sentiment4()


    # print ("\n\n\n\n")

    #######################################################################################

    # print ("List of tweets for celebrity %s -> " % (celeb_name[5]))

    for tweets in public_tweets5:
        # print ("***********************************")
        # print (tweets.text)
        analysis = TextBlob(tweets.text)
        # print ("Tweet sentiment.polarity :", analysis.sentiment.polarity)
        # print ("Tweet sentiment.subjectivity :", analysis.sentiment.subjectivity)

        # print ("The sentiment analysis of this tweet for  %s is:" % (celeb_name[5]))

        # if analysis.sentiment.polarity > 0:
        #     print 'positive'
        # if analysis.sentiment.polarity == 0:
        #     print 'neutral'
        # if analysis.sentiment.polarity < 0:
        #     print 'negative'

    def Overall_sentiment5():
        positive = analysis.sentiment.polarity > 0
        neutral = analysis.sentiment.polarity == 0
        negative = analysis.sentiment.polarity < 0

        if positive > negative:
            return "POSITIVE"

        elif positive < negative:
            return "NEGATIVE"
        else:
            return "NEUTRAL"

    # print ('\n\n\n')

    tweet_fifth = "The Overall sentiment for %s is :" % celeb_name[5], Overall_sentiment5()


    # print ("\n\n\n\n")

    #######################################################################################





    # print ("List of tweets for celebrity %s -> " % (celeb_name[6]))

    for tweets in public_tweets6:
        # print ("***********************************")
        # print (tweets.text)
        analysis = TextBlob(tweets.text)
        # print ("Tweet sentiment.polarity :", analysis.sentiment.polarity)
        # print ("Tweet sentiment.subjectivity :", analysis.sentiment.subjectivity)

        # print ("The sentiment analysis of this tweet for  %s is:" % (celeb_name[6]))

        # if analysis.sentiment.polarity > 0:
        #     print 'positive'
        # if analysis.sentiment.polarity == 0:
        #     print 'neutral'
        # if analysis.sentiment.polarity < 0:
        #     print 'negative'

    def Overall_sentiment6():
        positive = analysis.sentiment.polarity > 0
        neutral = analysis.sentiment.polarity == 0
        negative = analysis.sentiment.polarity < 0

        if positive > negative:
            return "POSITIVE"

        elif positive < negative:
            return "NEGATIVE"
        else:
            return "NEUTRAL"

    # print ('\n\n\n')

    tweet_sixth = "The Overall sentiment for %s is :" % celeb_name[6], Overall_sentiment6()


    # print ("\n\n\n\n")

    #######################################################################################

    # print ("List of tweets for celebrity %s -> " % (celeb_name[7]))

    for tweets in public_tweets7:
        # print ("***********************************")
        # print (tweets.text)
        analysis = TextBlob(tweets.text)
        # print ("Tweet sentiment.polarity :", analysis.sentiment.polarity)
        # print ("Tweet sentiment.subjectivity :", analysis.sentiment.subjectivity)

        # print ("The sentiment analysis of this tweet for  %s is:" % (celeb_name[7]))

        # if analysis.sentiment.polarity > 0:
        #     print 'positive'
        # if analysis.sentiment.polarity == 0:
        #     print 'neutral'
        # if analysis.sentiment.polarity < 0:
        #     print 'negative'

    def Overall_sentiment7():
        positive = analysis.sentiment.polarity > 0
        neutral = analysis.sentiment.polarity == 0
        negative = analysis.sentiment.polarity < 0

        if positive > negative:
            return "POSITIVE"

        elif positive < negative:
            return "NEGATIVE"
        else:
            return "NEUTRAL"

    # print ('\n\n\n')

    tweet_seventh = "The Overall sentiment for %s is :" % celeb_name[7], Overall_sentiment7()


    # print ("\n\n\n\n")

    #######################################################################################

    # print ("List of tweets for celebrity %s -> " % (celeb_name[8]))

    for tweets in public_tweets8:
        # print "***********************************"
        # print (tweets.text)
        analysis = TextBlob(tweets.text)
        # print ("Tweet sentiment.polarity :", analysis.sentiment.polarity)
        # print ("Tweet sentiment.subjectivity :", analysis.sentiment.subjectivity)

        # print ("The sentiment analysis of this tweet for  %s is:" % (celeb_name[8]))

        # if analysis.sentiment.polarity > 0:
        #     print 'positive'
        # if analysis.sentiment.polarity == 0:
        #     print 'neutral'
        # if analysis.sentiment.polarity < 0:
        #     print 'negative'

    def Overall_sentiment8():
        positive = analysis.sentiment.polarity > 0
        neutral = analysis.sentiment.polarity == 0
        negative = analysis.sentiment.polarity < 0

        if positive > negative:
            return "POSITIVE"

        elif positive < negative:
            return "NEGATIVE"
        else:
            return "NEUTRAL"

    # print ('\n\n\n')

    tweet_eighth = "The Overall sentiment for %s is :" % celeb_name[8], Overall_sentiment8()


    # print ("\n\n\n\n")

    #######################################################################################

    # print ("List of tweets for celebrity %s -> " % (celeb_name[9]))

    for tweets in public_tweets9:
        # print "***********************************"
        # print (tweets.text)
        analysis = TextBlob(tweets.text)
        # print ("Tweet sentiment.polarity :", analysis.sentiment.polarity)
        # print ("Tweet sentiment.subjectivity :", analysis.sentiment.subjectivity)

        # print ("The sentiment analysis of this tweet for  %s is:" % (celeb_name[9]))


        Overall_sentiment = []

        # if analysis.sentiment.polarity > 0:
        #     print 'positive'
        #
        # if analysis.sentiment.polarity == 0:
        #     print 'neutral'
        #
        # if analysis.sentiment.polarity < 0:
        #     print 'negative'

    def Overall_sentiment9():
        positive = analysis.sentiment.polarity > 0
        neutral = analysis.sentiment.polarity == 0
        negative = analysis.sentiment.polarity < 0

        if positive > negative:
            return "POSITIVE"

        elif positive < negative:
            return "NEGATIVE"
        else:
            return "NEUTRAL"

    # print ('\n\n\n')

    tweet_ninth = "The Overall sentiment for %s is :" % celeb_name[9], Overall_sentiment9()


    # print ("\n\n\n\n")

    print('++++++++++++++++++++++++++   Final  Output    +++++++++++++++++++++++++++++++++++++++++ ')
    print('#######################################################################################' '\n')

    print('--------------------------------------------------------------------------------------------')
    print("Name of Celebrity , celebrity image , Profession and Best Work : ")

    print(' Celebrities Name:  ' + (celeb_name[0]), '\n', ' Profession : ' + (
        celeb_detail[0].split(',')[0]), '\n', ' Best Work : ' + (
        celeb_detail[0].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[0]), '\n', tweet_zero, '\n')

    print(' Celebrities Name:  ' + (celeb_name[1]), '\n', ' Profession : ' + (
        celeb_detail[1].split(',')[0]), '\n', ' Best Work : ' + (
        celeb_detail[1].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[1]), '\n', tweet_first, '\n')

    print(' Celebrities Name:  ' + (celeb_name[2]), '\n', ' Profession : ' + (
        celeb_detail[2].split(',')[0]), '\n', ' Best Work : ' + (
        celeb_detail[2].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[2]), '\n', tweet_second, '\n')

    print(' Celebrities Name:  ' + (celeb_name[3]), '\n', ' Profession : ' + (
        celeb_detail[3].split(',')[0]), '\n', ' Best Work : ' + (
        celeb_detail[3].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[3]), '\n', tweet_third, '\n')

    print(' Celebrities Name:  ' + (celeb_name[4]), '\n', ' Profession : ' + (
        celeb_detail[4].split(',')[0]), '\n', ' Best Work : ' + (
        celeb_detail[4].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[4]), '\n', tweet_fourth, '\n')

    print(' Celebrities Name:  ' + (celeb_name[5]), '\n', ' Profession : ' + (
        celeb_detail[5].split(',')[0]), '\n', ' Best Work : ' + (
        celeb_detail[5].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[5]), '\n', tweet_fifth, '\n')

    print(' Celebrities Name:  ' + (celeb_name[6]), '\n', ' Profession : ' + (
        celeb_detail[6].split(',')[0]), '\n', ' Best Work : ' + (
        celeb_detail[6].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[6]), '\n', tweet_sixth, '\n')

    print(' Celebrities Name:  ' + (celeb_name[7]), '\n', ' Profession : ' + (
        celeb_detail[7].split(',')[0]), '\n', ' Best Work : ' + (
        celeb_detail[7].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[7]), '\n', tweet_seventh, '\n')

    print(' Celebrities Name:  ' + (celeb_name[8]), '\n', ' Profession : ' + (
        celeb_detail[8].split(',')[0]), '\n', ' Best Work : ' + (
        celeb_detail[8].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[8]), '\n', tweet_eighth, '\n')

    print(' Celebrities Name:  ' + (celeb_name[9]), '\n', ' Profession : ' + (
        celeb_detail[9].split(',')[0]), '\n', ' Best Work : ' + (
        celeb_detail[9].split(',')[1]), '\n', ' Celebrity Image:' + (celeb_images[9]), '\n', tweet_ninth, '\n')



# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++#









if __name__ == '__main__':
    Final_Output()

    # user = input('Press any key to Close: ')
    # print user
# Out:
# Sentiment Analysis for Birthday Celebrities:
# --------------------------------------------------------------------------------------------
# List of tweets for celebrity Dwayne Johnson ->
# RT @BodyBuildTweets: #GymAddict #Gainz #Muscle #Workout Dwayne Johnson Reveals His Bromance with Rob Gronkowski and Gives Out Quest.. https…
# Tweet sentiment.polarity : 0.0
# Tweet sentiment.subjectivity : 0.0
#
#
#
#
# Dwayne Johnson the rock la roca https://t.co/sKfZvbdh44
# Tweet sentiment.polarity : 0.0
# Tweet sentiment.subjectivity : 0.0
#
#
#
#
# Dwayne Johnson unveils plot details of ‘Rampage’ https://t.co/D9NXNuagrp https://t.co/oGu67OOB56
# Tweet sentiment.polarity : 0.0
# Tweet sentiment.subjectivity : 0.0
#
#
#
#
# Dwayne Johnson "The Rock" #quote #image https://t.co/JsQ434634W
# https://t.co/99XlqYoXyL https://t.co/w1AzFqlO0u
# Tweet sentiment.polarity : 0.0
# Tweet sentiment.subjectivity : 0.0
#
#
#
#
# #MásInfoEn40 Dwayne Johnson @TheRock es un actor, físico culturista y luchador profesional estadounidense. Ha... https://t.co/3NivAzQ9jq
# Tweet sentiment.polarity : 0.0
# Tweet sentiment.subjectivity : 0.0
#
#
#
#
# #Entertainment G.I. Joe: Retaliation ( #DVD; Widescreen ) #BruceWillis Dwayne Johnson The Rock!! https://t.co/3q6rMsepYl #eBay #Auction
# Tweet sentiment.polarity : 0.0
# Tweet sentiment.subjectivity : 0.0
#
#
#
#
# RT @ujfmbreakfast: Happy Birthday to Dwayne Douglas Johnson, also known by his ring name The Rock, who is an actor and professional.
#
# #UJF…
# Tweet sentiment.polarity : 0.45
# Tweet sentiment.subjectivity : 0.55
#
#
#
#
# Dwayne Johnson teams up with Disney Imagineers to re-design the "Jungle Cruise" attraction in D… https://t.co/w4HfUu60tc via @insidethemagic
# Tweet sentiment.polarity : 0.0
# Tweet sentiment.subjectivity : 0.0
#
#
#
#
# Dwayne Johnson’s description of Rampage is a beautiful piece of art https://t.co/c0NbrO67y2 via @Polygon
# Tweet sentiment.polarity : 0.85
# Tweet sentiment.subjectivity : 1.0
#
#
#
#
# Dwayne Johnson has revealed "Rampage" movie's details - https://t.co/sV3hHaI4MJ https://t.co/vpOgRaPBkN
# Tweet sentiment.polarity : 0.0
# Tweet sentiment.subjectivity : 0.0
#
#
#
#
# RT @DatelineDisney: Disney confirms @TheRock's visit to Imagineering for "Jungle Cruise" movie but denies plans to change classic ride http…
# Tweet sentiment.polarity : 0.16666666666666666
# Tweet sentiment.subjectivity : 0.16666666666666666
#
#
#
#
# RT @ujfmbreakfast: Happy Birthday to Dwayne Douglas Johnson, also known by his ring name The Rock, who is an actor and professional.
#
# #UJF…
# Tweet sentiment.polarity : 0.45
# Tweet sentiment.subjectivity : 0.55
#
#
#
#
# A Soopa Doopa Super Happpyyyy Birthday to you Dwayne Johnson @TheRock https://t.co/j5R4PfWeSn
# Tweet sentiment.polarity : 0.3333333333333333
# Tweet sentiment.subjectivity : 0.6666666666666666
#
#
#
#
# Don't sleep on the insane reach and universal appeal of Dwayne @TheRock Johnson. #Ballers #ThePeoplesEverything https://t.co/zdcsXZlQtx
# Tweet sentiment.polarity : -0.5
# Tweet sentiment.subjectivity : 0.5
#
#
#
#
# Happy Birthday Dwayne Johnson (Actor-Producer-The Other Guys,Fast Five,Pain &amp; Gain,Fast &amp; Furious 6,San ... -  -… https://t.co/2SI4y2Agi8
# Tweet sentiment.polarity : 0.3375
# Tweet sentiment.subjectivity : 0.6875
#
#
#
#
# List of tweets for celebrity Christine Baranski ->
# HAPPY BIRTHDAY CHRISTINE BARANSKI!! 👠🍸🎬 https://t.co/aXXHY6DitB
# Happy Birthday #ChristineBaranski  https://t.co/4pBtM7X4eE
# Celebrity birthdays for May 2nd: Engelbert Humperdinck 81, Christine Baranski 65, Dwayne Johnson 45, David Beckham 42, and Ellie Kemper 37.
# @tanynope @JimOHeir robin, claire danes, claire foy, keri, christine baranski  e elisabeth
# RT @Katiexlmx: IT'S CHRISTINE BARANSKI'S BIRTHDAY TOMORROW 😆I'M SO EXCITED!!!
# RT @berniewoIfe: I want a mean girls movie but with susan sarandon, jessica lange, isabelle huppert, meryl streep, christine baranski, jane…
# Tue, 02 May 2017, let us all send Christine Baranski the best Happy Birthday wishes today (#cebiday) (65)
# RT @perhcps: • does your mother know || mamma mia: i fucking LOVE mamma mia, it's my favorite. this number is so funny.  christine baranski…
# ♫Does Your Mother Know by Philip Michael, Christine Baranski, from #SoundHound with LiveLyrics® https://t.co/zbvHJYdA23
# RT @thegoodfight: Who run the world? 🙌👭 Christine Baranski is a role model and inspiration to women. Stream #TheGoodFight: https://t.co/e2y…
# RT @latelateshow: .@TheGoodFight's Christine Baranski had the best response after learning that @michaelsheen has named his 🍆 "The Great Ch…
# RT @KShee1993: Honestly, Christine Baranski in Mamma Mia is goals.
# CHRISTINE BARANSKI IS THE LOVE OF MY LIFE https://t.co/xVMWqTDdFM
# So I've made my Christine Baranski birthday edit for tomorrow....I'm just drafting a birthday paragraph now😂❤💕
# IT'S CHRISTINE BARANSKI'S BIRTHDAY TOMORROW 😆I'M SO EXCITED!!!
# ++++++++++++++++++++++++++   Final  Output    +++++++++++++++++++++++++++++++++++++++++
# #######################################################################################
#
# --------------------------------------------------------------------------------------------
# Name of Celebrity , celebrity image , Profession and Best Work :
#  Celebrities Name:  Dwayne Johnson
#   Profession : Actor
#   Best Work :  "Fast & Furious 6"
#   Celebrity Image:https://images-na.ssl-images-amazon.com/images/M/MV5BMTkyNDQ3NzAxM15BMl5BanBnXkFtZTgwODIwMTQ0NTE@._V1._CR0,0,1363,2010_SX40_SY59.jpg
#  ('The Overall sentiment for Dwayne Johnson is :', 'POSITIVE')
#
#  Celebrities Name:  Christine Baranski
#   Profession : Actress
#   Best Work :  "How the Grinch Stole Christmas"
#   Celebrity Image:https://images-na.ssl-images-amazon.com/images/M/MV5BMTUwMTYwMDUyM15BMl5BanBnXkFtZTcwNTk1MzQxMw@@._V1._CR14,0,271,400_SX40_SY59.jpg
#  ('The Overall sentiment for Christine Baranski is :', 'POSITIVE')
#
#  Celebrities Name:  Ellie Kemper
#   Profession : Actress
#   Best Work :  "21 Jump Street"
#   Celebrity Image:https://images-na.ssl-images-amazon.com/images/M/MV5BMjIzMDU3NzE4NV5BMl5BanBnXkFtZTcwODQyNTQzNA@@._V1._CR28,0,1388,2048_SX40_SY59.jpg
#  ('The Overall sentiment for Ellie Kemper is :', 'POSITIVE')
#
#  Celebrities Name:  Thomas McDonell
#   Profession : Actor
#   Best Work :  "The Forbidden Kingdom"
#   Celebrity Image:https://images-na.ssl-images-amazon.com/images/M/MV5BZjBmM2Y4M2MtNzg5My00NjBhLThhZTUtOTRhNTU2NTYyYzgyL2ltYWdlXkEyXkFqcGdeQXVyMTcwNDM4NjU@._V1._CR93,0,1094,1614_SX40_SY59.jpg
#  ('The Overall sentiment for Thomas McDonell is :', 'NEUTRAL')
#
#  Celebrities Name:  David Suchet
#   Profession : Actor
#   Best Work :  "A Perfect Murder"
#   Celebrity Image:https://images-na.ssl-images-amazon.com/images/M/MV5BMjc4Mjg3ODA0OV5BMl5BanBnXkFtZTcwNzI4Njg4OA@@._V1._CR54,0,1388,2048_SX40_SY59.jpg
#  ('The Overall sentiment for David Suchet is :', 'NEUTRAL')
#
#  Celebrities Name:  Robert Buckley
#   Profession : Actor
#   Best Work :  "Flirting with Forty"
#   Celebrity Image:https://images-na.ssl-images-amazon.com/images/M/MV5BMTc1MDUzNzc0OF5BMl5BanBnXkFtZTcwNDYzMjIwNQ@@._V1._CR47,0,1388,2048_SX40_SY59.jpg
#  ('The Overall sentiment for Robert Buckley is :', 'NEGATIVE')
#
#  Celebrities Name:  Gaius Charles
#   Profession : Actor
#   Best Work :  "Salt"
#   Celebrity Image:https://images-na.ssl-images-amazon.com/images/M/MV5BMTc0NDU0NzI0N15BMl5BanBnXkFtZTYwNjk4Njk3._V1._CR17,0,325,480_SX40_SY59.jpg
#  ('The Overall sentiment for Gaius Charles is :', 'NEUTRAL')
#
#  Celebrities Name:  David Beckham
#   Profession : Self
#   Best Work :  "The Class of 92"
#   Celebrity Image:https://images-na.ssl-images-amazon.com/images/M/MV5BMjA3ODA0MDI4OF5BMl5BanBnXkFtZTgwMjEyNzI3MDE@._V1._CR561,0,925,1365_SX40_SY59.jpg
#  ('The Overall sentiment for David Beckham is :', 'NEUTRAL')
#
#  Celebrities Name:  Kay Panabaker
#   Profession : Actress
#   Best Work :  "Monsters
#   Celebrity Image:https://images-na.ssl-images-amazon.com/images/M/MV5BMTg2NDA0NjI3Nl5BMl5BanBnXkFtZTYwNTY4Mzgy._V1._CR0,0,440,649_SX40_SY59.jpg
#  ('The Overall sentiment for Kay Panabaker is :', 'POSITIVE')
#
#  Celebrities Name:  Denyce Lawton
#   Profession : Actress
#   Best Work :  "Vlog"
#   Celebrity Image:https://images-na.ssl-images-amazon.com/images/M/MV5BMTA4MjM0NzQ4NjReQTJeQWpwZ15BbWU4MDU0NTk0MDAx._V1._CR0,0,2912,4295_SX40_SY59.jpg
#  ('The Overall sentiment for Denyce Lawton is :', 'POSITIVE')
